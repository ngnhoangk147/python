# %% [markdown]
# # Introduction
#
# Analysis of the Android app market in the Google Play store.
# Using plotly.express to create the charts
#
# **Data Source:** <br>
# App and review data was scraped from the Google Play Store by Lavanya Gupta in 2018. Original files listed [here](
# https://www.kaggle.com/lava18/google-play-store-apps).

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# # Data Cleaning
# - I found 'Rating' and 'Type' columns which have missing value -> remove missing value
# - Also, I saw the dataset had some duplicated rows -> remove duplicates

# %%
df_apps = pd.read_csv('apps.csv')
df_apps.sample(5)
# Out:
#                                  App     Category  Rating  Reviews  Size_MBs  \
# 501               Chronolink DX Lite       FAMILY     NaN        2      47.0
# 1761   Selfie With Champion AJ Style  PHOTOGRAPHY     5.0        2       7.5
# 7310                   ES App Locker        TOOLS     4.3    32207       3.4
# 153                           Ej-buy     BUSINESS     NaN        2       4.1
# 10679               Farm Heroes Saga         GAME     4.4  7614407      70.0
#
#           Installs  Type Price Content_Rating       Genres     Last_Updated  \
# 501             10  Free     0       Everyone       Puzzle  October 9, 2017
# 1761           500  Free     0       Everyone  Photography  January 8, 2018
# 7310     1,000,000  Free     0       Everyone        Tools  August 16, 2017
# 153              5  Free     0       Everyone     Business   August 2, 2018
# 10679  100,000,000  Free     0       Everyone       Casual    July 26, 2018
#
#       Android_Ver
# 501    4.1 and up
# 1761   3.2 and up
# 7310   2.1 and up
# 153    4.1 and up
# 10679  2.3 and up

# %%
df_apps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  int64
#  4   Size_MBs        10841 non-null  float64
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content_Rating  10841 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last_Updated    10841 non-null  object
#  11  Android_Ver     10839 non-null  object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 1016.5+ KB

# %%
df_apps.drop(['Android_Ver','Last_Updated'], axis=1, inplace=True)

# %% [markdown]
# ### Check and remove missing value

# %%
df_apps.isna().any()
# Out:
# App               False
# Category          False
# Rating             True
# Reviews           False
# Size_MBs          False
# Installs          False
# Type               True
# Price             False
# Content_Rating    False
# Genres            False
# dtype: bool

# %%
df_app_clean = df_apps.dropna()

# %%
df_app_clean.shape
# Out:
# (9367, 10)

# %% [markdown]
# ### Check and revmove duplicated value

# %%
df_app_clean.duplicated().any()
# Out:
# True

# %%
row_duplicates = df_app_clean[df_app_clean.duplicated()]
row_duplicates.sort_values(['App', 'Type', 'Price'], ascending=False)[:-10]
# Out:
#                                                      App            Category  \
# 10156                           trivago: Hotels & Travel    TRAVEL_AND_LOCAL
# 10159                           trivago: Hotels & Travel    TRAVEL_AND_LOCAL
# 9632   theScore: Live Sports Scores, News, Stats & Vi...              SPORTS
# 9634   theScore: Live Sports Scores, News, Stats & Vi...              SPORTS
# 9635   theScore: Live Sports Scores, News, Stats & Vi...              SPORTS
# ...                                                  ...                 ...
# 6488                             Ada - Your Health Guide             MEDICAL
# 6786                                     AdWords Express            BUSINESS
# 5686                         Accounting App - Zoho Books            BUSINESS
# 3242                                        ASCCP Mobile             MEDICAL
# 7242                          ABC News - US & World News  NEWS_AND_MAGAZINES
#
#        Rating  Reviews  Size_MBs    Installs  Type  Price Content_Rating  \
# 10156     4.2   219848      12.0  50,000,000  Free      0       Everyone
# 10159     4.2   219848      12.0  50,000,000  Free      0       Everyone
# 9632      4.4   133825      34.0  10,000,000  Free      0   Everyone 10+
# 9634      4.4   133833      34.0  10,000,000  Free      0   Everyone 10+
# 9635      4.4   133833      34.0  10,000,000  Free      0   Everyone 10+
# ...       ...      ...       ...         ...   ...    ...            ...
# 6488      4.7    87418      14.0   1,000,000  Free      0       Everyone
# 6786      4.1     7149      11.0   1,000,000  Free      0       Everyone
# 5686      4.5     3079       8.5     100,000  Free      0       Everyone
# 3242      4.5       63      25.0      10,000  Paid  $9.99       Everyone
# 7242      4.0    18976      35.0   1,000,000  Free      0   Everyone 10+
#
#                  Genres
# 10156    Travel & Local
# 10159    Travel & Local
# 9632             Sports
# 9634             Sports
# 9635             Sports
# ...                 ...
# 6488            Medical
# 6786           Business
# 5686           Business
# 3242            Medical
# 7242   News & Magazines
#
# [466 rows x 10 columns]

# %%
df_app_clean = df_app_clean.sort_values(['App', 'Reviews'])
df_app_clean = df_app_clean.drop_duplicates(['App', 'Type', 'Price'], keep='last')

# %% [markdown]
# # Data Transformation
# - 'Installs' and 'Price' columns should be numeric data type -> remove the unnecessary characters and convert to numeric data type

# %%
df_app_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8199 entries, 7523 to 7574
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8199 non-null   object
#  1   Category        8199 non-null   object
#  2   Rating          8199 non-null   float64
#  3   Reviews         8199 non-null   int64
#  4   Size_MBs        8199 non-null   float64
#  5   Installs        8199 non-null   object
#  6   Type            8199 non-null   object
#  7   Price           8199 non-null   object
#  8   Content_Rating  8199 non-null   object
#  9   Genres          8199 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 704.6+ KB

# %%
df_app_clean['Installs'] = df_app_clean['Installs'].astype(str).str.replace(',','')
df_app_clean['Installs'] = pd.to_numeric(df_app_clean['Installs'])

# %%
df_app_clean['Price'] = df_app_clean['Price'].astype(str).str.replace('$','')
df_app_clean['Price'] = pd.to_numeric(df_app_clean['Price'])
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_12120\1964641029.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_app_clean['Price'] = df_app_clean['Price'].astype(str).str.replace('$','')

# %%
df_app_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8199 entries, 7523 to 7574
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8199 non-null   object
#  1   Category        8199 non-null   object
#  2   Rating          8199 non-null   float64
#  3   Reviews         8199 non-null   int64
#  4   Size_MBs        8199 non-null   float64
#  5   Installs        8199 non-null   int64
#  6   Type            8199 non-null   object
#  7   Price           8199 non-null   float64
#  8   Content_Rating  8199 non-null   object
#  9   Genres          8199 non-null   object
# dtypes: float64(3), int64(2), object(5)
# memory usage: 704.6+ KB

# %% [markdown]
# #### Add a new column 'Estimated Revenue'

# %%
df_app_clean['Estimated Revenue'] = df_app_clean['Price']*df_app_clean['Installs']

# %%
df_app_clean.sort_values('Price', ascending=False)[:20]
# Out:
#                                  App   Category  Rating  Reviews   Size_MBs  \
# 3946        I'm Rich - Trump Edition  LIFESTYLE     3.6      275   7.300000
# 2775                   I Am Rich Pro     FAMILY     4.4      201   2.700000
# 3114                       I am Rich    FINANCE     4.3      180   3.800000
# 1331          most expensive app (H)     FAMILY     4.3        6   1.500000
# 3554                      💎 I'm rich  LIFESTYLE     3.8      718  26.000000
# 3145              I am rich(premium)    FINANCE     3.5      472   0.942383
# 2461              I AM RICH PRO PLUS    FINANCE     4.0       36  41.000000
# 4606               I Am Rich Premium    FINANCE     4.1     1867   4.700000
# 1946  I am rich (Most expensive app)    FINANCE     4.1      129   2.700000
# 5765                       I am rich  LIFESTYLE     3.8     3547   1.800000
# 2394                      I am Rich!    FINANCE     3.8       93  22.000000
# 3221                  I am Rich Plus     FAMILY     4.0      856   8.700000
# 3897                       I Am Rich     FAMILY     3.6      217   4.900000
# 2193             I am extremely Rich  LIFESTYLE     2.9       41   2.900000
# 3856                   I am rich VIP  LIFESTYLE     3.8      411   2.600000
# 2282       Vargo Anesthesia Mega App    MEDICAL     4.6       92  32.000000
# 1407                    LTC AS Legal    MEDICAL     4.0        6   1.300000
# 2629                I am Rich Person  LIFESTYLE     4.2      134   1.800000
# 2482         A Manual of Acupuncture    MEDICAL     3.5      214  68.000000
# 504        AP Art History Flashcards     FAMILY     5.0        1  96.000000
#
#       Installs  Type   Price Content_Rating         Genres  Estimated Revenue
# 3946     10000  Paid  400.00       Everyone      Lifestyle          4000000.0
# 2775      5000  Paid  399.99       Everyone  Entertainment          1999950.0
# 3114      5000  Paid  399.99       Everyone        Finance          1999950.0
# 1331       100  Paid  399.99       Everyone  Entertainment            39999.0
# 3554     10000  Paid  399.99       Everyone      Lifestyle          3999900.0
# 3145      5000  Paid  399.99       Everyone        Finance          1999950.0
# 2461      1000  Paid  399.99       Everyone        Finance           399990.0
# 4606     50000  Paid  399.99       Everyone        Finance         19999500.0
# 1946      1000  Paid  399.99           Teen        Finance           399990.0
# 5765    100000  Paid  399.99       Everyone      Lifestyle         39999000.0
# 2394      1000  Paid  399.99       Everyone        Finance           399990.0
# 3221     10000  Paid  399.99       Everyone  Entertainment          3999900.0
# 3897     10000  Paid  389.99       Everyone  Entertainment          3899900.0
# 2193      1000  Paid  379.99       Everyone      Lifestyle           379990.0
# 3856     10000  Paid  299.99       Everyone      Lifestyle          2999900.0
# 2282      1000  Paid   79.99       Everyone        Medical            79990.0
# 1407       100  Paid   39.99       Everyone        Medical             3999.0
# 2629      1000  Paid   37.99       Everyone      Lifestyle            37990.0
# 2482      1000  Paid   33.99       Everyone        Medical            33990.0
# 504         10  Paid   29.99     Mature 17+      Education              299.9

# %% [markdown]
# #### Remove the rows that related 'I am Rich' appps
# Many apps have the content like 'I am rich'. They have the high price, the lowest price is 2299.99
# -> remove these rows

# %%
df_clean_app = df_app_clean[df_app_clean['Price'] < 250]

# %% [markdown]
# ### The hightest rated Apps

# %%
df_clean_app.sort_values(['Rating','Reviews'], ascending=False)[:10]
# Out:
#                                                     App            Category  \
# 2095                                         Ríos de Fe           LIFESTYLE
# 2438  FD Calculator (EMI, SIP, RD & Loan Eligilibility)             FINANCE
# 3115                                         Oración CX           LIFESTYLE
# 2107                     Barisal University App-BU Face              FAMILY
# 2069                                         Master E.K              FAMILY
# 1968                                            CL REPL               TOOLS
# 790                                              AJ Cam         PHOTOGRAPHY
# 1275   AI Today : Artificial Intelligence News & AI 101  NEWS_AND_MAGAZINES
# 2544                        CS & IT Interview Questions              FAMILY
# 1789                                            Ek Vote        PRODUCTIVITY
#
#       Rating  Reviews  Size_MBs  Installs  Type  Price Content_Rating  \
# 2095     5.0      141      15.0      1000  Free    0.0       Everyone
# 2438     5.0      104       2.3      1000  Free    0.0       Everyone
# 3115     5.0      103       3.8      5000  Free    0.0       Everyone
# 2107     5.0      100      10.0      1000  Free    0.0       Everyone
# 2069     5.0       90      19.0      1000  Free    0.0       Everyone
# 1968     5.0       47      17.0      1000  Free    0.0       Everyone
# 790      5.0       44       2.8       100  Free    0.0       Everyone
# 1275     5.0       43       2.3       100  Free    0.0       Everyone
# 2544     5.0       43       3.3      1000  Free    0.0       Everyone
# 1789     5.0       43       6.2       500  Free    0.0       Everyone
#
#                 Genres  Estimated Revenue
# 2095         Lifestyle                0.0
# 2438           Finance                0.0
# 3115         Lifestyle                0.0
# 2107         Education                0.0
# 2069         Education                0.0
# 1968             Tools                0.0
# 790        Photography                0.0
# 1275  News & Magazines                0.0
# 2544         Education                0.0
# 1789      Productivity                0.0

# %% [markdown]
# ### 5 Apps with the most reviews

# %%
df_clean_app.sort_values('Reviews', ascending = False)[:5]
# Out:
#                                             App       Category  Rating  \
# 10805                                  Facebook         SOCIAL     4.1
# 10789                        WhatsApp Messenger  COMMUNICATION     4.4
# 10808                                 Instagram         SOCIAL     4.5
# 10790  Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# 10652                            Clash of Clans           GAME     4.6
#
#         Reviews  Size_MBs    Installs  Type  Price Content_Rating  \
# 10805  78158306       5.3  1000000000  Free    0.0           Teen
# 10789  69119316       3.5  1000000000  Free    0.0       Everyone
# 10808  66577446       5.3  1000000000  Free    0.0           Teen
# 10790  56646578       3.5  1000000000  Free    0.0       Everyone
# 10652  44893888      98.0   100000000  Free    0.0   Everyone 10+
#
#               Genres  Estimated Revenue
# 10805         Social                0.0
# 10789  Communication                0.0
# 10808         Social                0.0
# 10790  Communication                0.0
# 10652       Strategy                0.0

# %% [markdown]
# # Visualization

# %% [markdown]
# ### Top 15 Categories with the most apps

# %%
categories = df_clean_app['Category'].value_counts()
print(categories)
print(f'\nNumber of categories: {len(categories)}')
# Out:
# FAMILY                 1649
# GAME                    898
# TOOLS                   720
# PRODUCTIVITY            301
# PERSONALIZATION         298
# LIFESTYLE               297
# FINANCE                 296
# MEDICAL                 291
# PHOTOGRAPHY             263
# BUSINESS                263
# SPORTS                  260
# COMMUNICATION           256
# HEALTH_AND_FITNESS      244
# NEWS_AND_MAGAZINES      204
# SOCIAL                  203
# TRAVEL_AND_LOCAL        187
# SHOPPING                180
# BOOKS_AND_REFERENCE     169
# VIDEO_PLAYERS           149
# DATING                  134
# MAPS_AND_NAVIGATION     118
# EDUCATION               104
# FOOD_AND_DRINK           94
# ENTERTAINMENT            86
# AUTO_AND_VEHICLES        73
# WEATHER                  72
# LIBRARIES_AND_DEMO       64
# HOUSE_AND_HOME           61
# ART_AND_DESIGN           59
# COMICS                   54
# PARENTING                50
# EVENTS                   45
# BEAUTY                   42
# Name: Category, dtype: int64
#
# Number of categories: 33

# %%
bar = px.bar(categories, x=categories.index[:15], y=categories.values[:15],
             color = categories.values[:15],
             color_continuous_scale = 'Tealgrn',
            title='Number of apps by Category')
bar.update_layout(xaxis_title='Category', yaxis_title='Number of apps',
                 coloraxis_showscale = False)
bar.show()
# Out:
# <div>                            <div id="7b451378-20a5-491c-9078-4f8d0fc02e03" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7b451378-20a5-491c-9078-4f8d0fc02e03")) {                    Plotly.newPlot(                        "7b451378-20a5-491c-9078-4f8d0fc02e03",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<br>color=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[1649,898,720,301,298,297,296,291,263,263,260,256,244,204,203],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["FAMILY","GAME","TOOLS","PRODUCTIVITY","PERSONALIZATION","LIFESTYLE","FINANCE","MEDICAL","PHOTOGRAPHY","BUSINESS","SPORTS","COMMUNICATION","HEALTH_AND_FITNESS","NEWS_AND_MAGAZINES","SOCIAL"],"xaxis":"x","y":[1649,898,720,301,298,297,296,291,263,263,260,256,244,204,203],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0, ...

# %% [markdown]
# Evaluating top 15 categories with the most apps
# - 'Family' is the category with the most apps, there are 1649 apps which belong to this category
# - 'Game' and 'Tools' are respectively the categories with the 2nd (898) and 3rd (720) highest number of apps
# - The next categories have the number of apps from about 200-300

# %% [markdown]
# ### Content Rating component

# %%
cont_rating = df_clean_app['Content_Rating'].value_counts()
cont_rating
# Out:
# Everyone           6607
# Teen                911
# Mature 17+          357
# Everyone 10+        305
# Adults only 18+       3
# Unrated               1
# Name: Content_Rating, dtype: int64

# %%
pie = px.pie(cont_rating, values = cont_rating.values, names=cont_rating.index,
            title='Label Component Percentage')
pie.show()
# Out:
# <div>                            <div id="25001407-1bbd-4631-b79d-8047ef5f6c34" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("25001407-1bbd-4631-b79d-8047ef5f6c34")) {                    Plotly.newPlot(                        "25001407-1bbd-4631-b79d-8047ef5f6c34",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"index=%{label}<br>value=%{value}<extra></extra>","labels":["Everyone","Teen","Mature 17+","Everyone 10+","Adults only 18+","Unrated"],"legendgroup":"","name":"","showlegend":true,"values":[6607,911,357,305,3,1],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":" ...
#
# var gd = document.getElementById('25001407-1bbd-4631-b79d-8047ef5f6c

# %% [markdown]
# - Most apps (80.7%) are labeled 'Everyone', 11.1% for 'Teen'
# - The rest are 'Mature 17+', 'Everyone 10+', 'Adults only 18+' and 'Unrated'

# %%
category_download = df_clean_app.groupby('Category', as_index=False).agg(Downloads=('Installs','sum'))
category_download.sort_values('Downloads', inplace=True)

# %%
h_bar = px.bar(category_download, 
               x=category_download['Downloads'][-15:], 
               y=category_download['Category'][-15:],
               color = category_download['Downloads'][-15:],
              color_continuous_scale = 'Tealgrn',
              title = 'Top 15 Categories with the most installs')
h_bar.update_layout(xaxis_title = 'Number of installs',
                    yaxis_title = 'Category',
                    coloraxis_showscale=False)
h_bar.show()
# Out:
# <div>                            <div id="64f23f37-bc26-4e0e-876c-28f18e4c4cc3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("64f23f37-bc26-4e0e-876c-28f18e4c4cc3")) {                    Plotly.newPlot(                        "64f23f37-bc26-4e0e-876c-28f18e4c4cc3",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<br>color=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[1096431465,1144006220,1400331540,1532352930,1665791655,2369110650,2894859300,3931797200,4658143130,5487841475,5793070180,6236955490,8100724500,11038241530,13447762717],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[1096431465,1144006220,1400331540,1532352930,1665791655,2369110650,2894859300,3931797200,4658143130,5487841475,5793070180,6236955490,8100724500,11038241530,13447762717],"xaxis":"x","y":["SPORTS","HEALTH_AND_FITNESS","SHOPPING","PERSONALIZATION","BOOKS_AND_REFERENCE","NEWS_AND_MAGAZINES","TRAVEL_AND_LOCAL","VIDEO_PLAYERS","PHOTOGRAPHY","SOCIAL","PRODUCTIVITY","FAMILY","TOOLS","COMMUNICATION","GAME"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44 ...

# %% [markdown]
# ### Category Concentration - Downloads vs. Number of Apps

# %%
cate_install_apps = df_clean_app.groupby('Category', as_index=False).\
                        agg(Downloads=('Installs','sum'), Nb_Apps=('App','count'))

# %%
scatter = px.scatter(cate_install_apps, x='Nb_Apps', y='Downloads', color='Downloads', size='Nb_Apps',
                    title = 'Category Concentration - Downloads vs. Number of Apps', hover_name='Category')
scatter.update_layout(xaxis_title='Number of Apps',
                     yaxis=dict(type='log'))
scatter.show()
# Out:
# <div>                            <div id="46facdb8-4b11-4c1c-8008-cb7e7cf5c0c8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("46facdb8-4b11-4c1c-8008-cb7e7cf5c0c8")) {                    Plotly.newPlot(                        "46facdb8-4b11-4c1c-8008-cb7e7cf5c0c8",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Nb_Apps=%{marker.size}<br>Downloads=%{marker.color}<extra></extra>","hovertext":["ART_AND_DESIGN","AUTO_AND_VEHICLES","BEAUTY","BOOKS_AND_REFERENCE","BUSINESS","COMICS","COMMUNICATION","DATING","EDUCATION","ENTERTAINMENT","EVENTS","FAMILY","FINANCE","FOOD_AND_DRINK","GAME","HEALTH_AND_FITNESS","HOUSE_AND_HOME","LIBRARIES_AND_DEMO","LIFESTYLE","MAPS_AND_NAVIGATION","MEDICAL","NEWS_AND_MAGAZINES","PARENTING","PERSONALIZATION","PHOTOGRAPHY","PRODUCTIVITY","SHOPPING","SOCIAL","SPORTS","TOOLS","TRAVEL_AND_LOCAL","VIDEO_PLAYERS","WEATHER"],"legendgroup":"","marker":{"color":[113233100,53129800,26916200,1665791655,697018120,44931100,11038241530,140912410,188851000,984660000,15949410,6236955490,455249400,211677750,13447762717,1144006220,97072000,52083000,503611120,503267560,38252676,2369110650,31116110,1532352930,4658143130,5793070180,1400331540,5487841475,1096431465,8100724500,2894859300,3931797200,361096500],"coloraxis":"coloraxis","size":[59,73,42,169,263,54,256,134,104,86,45,1649,296,94,898,244,61,64,297,118,291,204,50,298,263,301,180,203,260,720,187,149,72],"sizemode":"area","sizeref":4.1225,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[59,73,42,169,263,54,256,134,104,86,45,1649,296,94,898,244,61,64,297,118,291,204,50,298,263,301,180,203,260,720,187,149,72],"xaxis":"x","y":[113233100,53129800,26916200,1665791655,697018120,44931100,11038241530,140912410,188851000,984660000,15949410,6236955490,455249400,211677750,13447762717,1144006220,97072000,52083000,503611120,503267560,38252676,2369110650,31116110,1532352930,4658143130,5793070180,1400331540,5487841475,1096431465,8100724500,2894859300,3931797200,361096500],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333 ...

# %% [markdown]
# ### Genres with the most apps

# %%
df_clean_app['Genres'].value_counts()
# Out:
# Tools                                  719
# Entertainment                          467
# Education                              429
# Productivity                           301
# Personalization                        298
#                                       ...
# Arcade;Pretend Play                      1
# Casual;Music & Video                     1
# Art & Design;Pretend Play                1
# Health & Fitness;Action & Adventure      1
# Board;Pretend Play                       1
# Name: Genres, Length: 114, dtype: int64

# %%
stack = df_clean_app['Genres'].astype(str).str.split(';', expand=True).stack()
number_stack = stack.value_counts()
print(len(number_stack))
# Out:
# 53

# %%
bar = px.bar(number_stack, x=number_stack.index[:15], y=number_stack.values[:15],
            color=number_stack.values[:15], color_continuous_scale = 'Tealgrn',
            title='Top 15 Genres with the most Apps')
bar.update_layout(xaxis_title='Genres', yaxis_title='Number of Apps', coloraxis_showscale=False)
bar.show()
# Out:
# <div>                            <div id="e33890b5-fbcb-4b09-a828-8907475c0e2e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e33890b5-fbcb-4b09-a828-8907475c0e2e")) {                    Plotly.newPlot(                        "e33890b5-fbcb-4b09-a828-8907475c0e2e",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<br>color=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[720,587,498,304,301,298,298,296,291,270,263,263,257,246,217],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Tools","Education","Entertainment","Action","Productivity","Personalization","Lifestyle","Finance","Medical","Sports","Photography","Business","Communication","Health & Fitness","Casual"],"xaxis":"x","y":[720,587,498,304,301,298,298,296,291,270,263,263,257,246,217],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"tic ...

# %% [markdown]
# ### Free and Paid Apps by Category

# %%
free_paid =  df_clean_app.groupby(['Category', 'Type'], as_index=False).agg(Nb_Apps=('App','count'))

# %%
free_paid_bar = px.bar(free_paid, x='Category', y='Nb_Apps', color='Type', barmode='group')
free_paid_bar.update_layout(yaxis=dict(type='log'), xaxis={'categoryorder':'total descending'})
free_paid_bar.show()
# Out:
# <div>                            <div id="e82b66df-9062-4876-917d-1fde5c44db27" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e82b66df-9062-4876-917d-1fde5c44db27")) {                    Plotly.newPlot(                        "e82b66df-9062-4876-917d-1fde5c44db27",                        [{"alignmentgroup":"True","hovertemplate":"Type=Free<br>Category=%{x}<br>Nb_Apps=%{y}<extra></extra>","legendgroup":"Free","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Free","offsetgroup":"Free","orientation":"v","showlegend":true,"textposition":"auto","x":["ART_AND_DESIGN","AUTO_AND_VEHICLES","BEAUTY","BOOKS_AND_REFERENCE","BUSINESS","COMICS","COMMUNICATION","DATING","EDUCATION","ENTERTAINMENT","EVENTS","FAMILY","FINANCE","FOOD_AND_DRINK","GAME","HEALTH_AND_FITNESS","HOUSE_AND_HOME","LIBRARIES_AND_DEMO","LIFESTYLE","MAPS_AND_NAVIGATION","MEDICAL","NEWS_AND_MAGAZINES","PARENTING","PERSONALIZATION","PHOTOGRAPHY","PRODUCTIVITY","SHOPPING","SOCIAL","SPORTS","TOOLS","TRAVEL_AND_LOCAL","VIDEO_PLAYERS","WEATHER"],"xaxis":"x","y":[56,72,42,161,254,54,234,131,102,84,45,1497,289,92,822,233,61,64,284,113,228,202,48,233,248,283,178,201,238,657,179,145,65],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Type=Paid<br>Category=%{x}<br>Nb_Apps=%{y}<extra></extra>","legendgroup":"Paid","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Paid","offsetgroup":"Paid","orientation":"v","showlegend":true,"textposition":"auto","x":["ART_AND_DESIGN","AUTO_AND_VEHICLES","BOOKS_AND_REFERENCE","BUSINESS","COMMUNICATION","DATING","EDUCATION","ENTERTAINMENT","FAMILY","FINANCE","FOOD_AND_DRINK","GAME","HEALTH_AND_FITNESS","LIFESTYLE","MAPS_AND_NAVIGATION","MEDICAL","NEWS_AND_MAGAZINES","PARENTING","PERSONALIZATION","PHOTOGRAPHY","PRODUCTIVITY","SHOPPING","SOCIAL","SPORTS","TOOLS","TRAVEL_AND_LOCAL","VIDEO_PLAYERS","WEATHER"],"xaxis":"x","y":[3,1,8,9,22,3,2,2,152,7,2,76,11,13,5,63,2,2,65,15,18,2,2,22,63,8,4,7],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b ...

# %% [markdown]
# ### Distribution

# %%
box = px.box(df_clean_app, x='Type', y='Installs', color='Type',
            title = 'Distribution of number of installs by Free and Paid type')
box.update_layout(yaxis=dict(type='log'))
box.show()
# Out:
# <div>                            <div id="ab0d70c3-a77f-447e-ac70-86f517fb74df" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ab0d70c3-a77f-447e-ac70-86f517fb74df")) {                    Plotly.newPlot(                        "ab0d70c3-a77f-447e-ac70-86f517fb74df",                        [{"alignmentgroup":"True","hovertemplate":"Type=%{x}<br>Installs=%{y}<extra></extra>","legendgroup":"Free","marker":{"color":"#636efa"},"name":"Free","notched":false,"offsetgroup":"Free","orientation":"v","showlegend":true,"x":["Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free"," ...

# %%
paid_app = df_clean_app[df_clean_app['Type'] == 'Paid']

# %%
paid_box = px.box(paid_app, x='Category', y='Price',
                 title='Distribution of Price by Category')
paid_box.update_layout(yaxis=dict(type='log'), xaxis={'categoryorder':'max descending'})
paid_box.show()
# Out:
# <div>                            <div id="2375d971-564b-47cc-ba20-d9c92309f390" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2375d971-564b-47cc-ba20-d9c92309f390")) {                    Plotly.newPlot(                        "2375d971-564b-47cc-ba20-d9c92309f390",                        [{"alignmentgroup":"True","hovertemplate":"Category=%{x}<br>Price=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["COMMUNICATION","BOOKS_AND_REFERENCE","BOOKS_AND_REFERENCE","COMMUNICATION","MEDICAL","COMMUNICATION","GAME","FAMILY","FAMILY","MEDICAL","LIFESTYLE","LIFESTYLE","PRODUCTIVITY","TOOLS","PERSONALIZATION","COMMUNICATION","FAMILY","TOOLS","PHOTOGRAPHY","PERSONALIZATION","PERSONALIZATION","PERSONALIZATION","GAME","DATING","FAMILY","FAMILY","PERSONALIZATION","MEDICAL","MEDICAL","TOOLS","SPORTS","SPORTS","MEDICAL","PRODUCTIVITY","PRODUCTIVITY","TOOLS","TOOLS","TOOLS","TOOLS","TOOLS","TOOLS","TOOLS","GAME","FAMILY","FAMILY","PHOTOGRAPHY","BOOKS_AND_REFERENCE","LIFESTYLE","FAMILY","FAMILY","GAME","TOOLS","MEDICAL","PERSONALIZATION","PERSONALIZATION","FAMILY","TOOLS","MEDICAL","PHOTOGRAPHY","PERSONALIZATION","GAME","FAMILY","TOOLS","FAMILY","GAME","GAME","FINANCE","BOOKS_AND_REFERENCE","MEDICAL","PERSONALIZATION","GAME","PERSONALIZATION","TOOLS","TOOLS","VIDEO_PLAYERS","GAME","BUSINESS","FINANCE","PARENTING","MAPS_AND_NAVIGATION","GAME","FAMILY","FAMILY","SPORTS","SPORTS","SPORTS","SPORTS","TOOLS","TOOLS","TOOLS","FAMILY","HEALTH_AND_FITNESS","PHOTOGRAPHY","PERSONALIZATION","FAMILY","GAME","FINANCE","TOOLS","PHOTOGRAPHY","GAME","MEDICAL","MEDICAL","FAMILY","FAMILY","FAMILY","FAMILY","LIFESTYLE","MEDICAL","MAPS_AND_NAVIGATION","PRODUCTIVITY","TOOLS","PERSONALIZATION","FAMILY","LIFESTYLE","TOOLS","MEDICAL","MAPS_AND_NAVIGATION","TOOLS","FAMILY","PERSONALIZATION","BUSINESS","PERSONALIZATION","FAMILY","FAMILY","GAME","COMMUNICATION","COMMUNICATION","COMMUNICATION","TOOLS","MEDICAL","DATING","PRODUCTIVITY","GAME","PRODUCTIVITY","PHOTOGRAPHY","PHOTOGRAPHY","TRAVEL_AND_LOCAL","FAMILY","MEDICAL","FAMILY","FAMILY","FAMILY","FAMILY","GAME","FAMILY","PERSONALIZATION","GAME","PERSONALIZATION","MEDICAL","FAMILY","GAME","TRAVEL_AND_LOCAL","TOOLS","BUSINESS","PRODUCTIVITY","FAMILY","FAMILY","FAMILY","FAMILY","FAMILY","FAMILY","FAMILY","FAMILY","BUSINESS","TOOLS","PERSONALIZATION","HEALTH_AND_FITNESS","PERSONALIZATION","PERSONALIZATION","FAMILY","COMMUNICATION","TOOLS","TOOLS","FAMILY","FAMILY","FAMILY","PERSONALIZATION","MEDICAL","PERSONALIZATION","MEDICAL","GAME","BOOKS_AND_REFERENCE","GAME","GAME","FAMILY","HEALTH_AND_FITNESS","FAMILY","FAMILY","FAMILY","FAMILY","FAMILY","FAMILY","FAMILY","FAMILY","GAME","GAME","FAMILY","TOOLS","TOOLS","BOOKS_AND_REFERENCE","GAME","TOOLS","FAMILY","PERSONALIZATION","MEDICAL","MEDICAL","MEDICAL","MEDICAL","MEDICAL","PRODUCTIVITY","PERSONALIZATION","TOOLS","FAMILY","TOOLS","FAMILY","MEDICAL","MEDICAL","FAMILY","COMMUNICATION","GAME","FAMILY","PHOTOGRAPHY","PRODUCTIVITY","PERSONALIZATION","MEDICAL","FAMILY","FAMILY","SPORTS","SPORTS","SPORTS","PERSONALIZATION","TOOLS","PHOTOGRAPHY","FAMILY","GAME","HEALTH_AND_FITNESS","TOOLS","FINANCE","GAME","FAMILY","GAME","GAME","GAME","TOOLS","FAMILY","WEATHER","VIDEO_PLAYERS","SPORTS","SPORTS","FAMILY","TOOLS","GAME","FAMILY","TOOLS","PERSONALIZATION","SPORTS","TOOLS","TOOLS","TOOLS","PERSONALIZATION","GAME","GAME","GAME","PERSONALIZATION","SPORTS","GAME","TRAVEL_AND_LOCAL","FAMILY","FAMILY","FAMILY","FAMILY","FAMILY","LIFESTYLE","PERSONALIZATION","FAMILY","FAMILY","BOOKS_AND_REFERENCE","FAMILY","GAME","MEDICAL","MEDICAL","SPORTS","TOOLS","GAME","LIFESTYLE","LIFESTYLE","FINANCE","MEDICAL","FAMILY","MEDICAL","FAMILY","MEDICAL","FAMILY","PRODUCTIVIT ...

# %%
paid_box = px.box(paid_app, x='Category', y='Estimated Revenue',
                 title='Distribution of Revenue by Category')
paid_box.update_layout(yaxis=dict(type='log'), xaxis = {'categoryorder':'max descending'})
paid_box.show()
# Out:
# <div>                            <div id="246d9677-cd72-45e5-a5af-34a96743d2c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("246d9677-cd72-45e5-a5af-34a96743d2c5")) {                    Plotly.newPlot(                        "246d9677-cd72-45e5-a5af-34a96743d2c5",                        [{"alignmentgroup":"True","hovertemplate":"Category=%{x}<br>Estimated Revenue=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["COMMUNICATION","BOOKS_AND_REFERENCE","BOOKS_AND_REFERENCE","COMMUNICATION","MEDICAL","COMMUNICATION","GAME","FAMILY","FAMILY","MEDICAL","LIFESTYLE","LIFESTYLE","PRODUCTIVITY","TOOLS","PERSONALIZATION","COMMUNICATION","FAMILY","TOOLS","PHOTOGRAPHY","PERSONALIZATION","PERSONALIZATION","PERSONALIZATION","GAME","DATING","FAMILY","FAMILY","PERSONALIZATION","MEDICAL","MEDICAL","TOOLS","SPORTS","SPORTS","MEDICAL","PRODUCTIVITY","PRODUCTIVITY","TOOLS","TOOLS","TOOLS","TOOLS","TOOLS","TOOLS","TOOLS","GAME","FAMILY","FAMILY","PHOTOGRAPHY","BOOKS_AND_REFERENCE","LIFESTYLE","FAMILY","FAMILY","GAME","TOOLS","MEDICAL","PERSONALIZATION","PERSONALIZATION","FAMILY","TOOLS","MEDICAL","PHOTOGRAPHY","PERSONALIZATION","GAME","FAMILY","TOOLS","FAMILY","GAME","GAME","FINANCE","BOOKS_AND_REFERENCE","MEDICAL","PERSONALIZATION","GAME","PERSONALIZATION","TOOLS","TOOLS","VIDEO_PLAYERS","GAME","BUSINESS","FINANCE","PARENTING","MAPS_AND_NAVIGATION","GAME","FAMILY","FAMILY","SPORTS","SPORTS","SPORTS","SPORTS","TOOLS","TOOLS","TOOLS","FAMILY","HEALTH_AND_FITNESS","PHOTOGRAPHY","PERSONALIZATION","FAMILY","GAME","FINANCE","TOOLS","PHOTOGRAPHY","GAME","MEDICAL","MEDICAL","FAMILY","FAMILY","FAMILY","FAMILY","LIFESTYLE","MEDICAL","MAPS_AND_NAVIGATION","PRODUCTIVITY","TOOLS","PERSONALIZATION","FAMILY","LIFESTYLE","TOOLS","MEDICAL","MAPS_AND_NAVIGATION","TOOLS","FAMILY","PERSONALIZATION","BUSINESS","PERSONALIZATION","FAMILY","FAMILY","GAME","COMMUNICATION","COMMUNICATION","COMMUNICATION","TOOLS","MEDICAL","DATING","PRODUCTIVITY","GAME","PRODUCTIVITY","PHOTOGRAPHY","PHOTOGRAPHY","TRAVEL_AND_LOCAL","FAMILY","MEDICAL","FAMILY","FAMILY","FAMILY","FAMILY","GAME","FAMILY","PERSONALIZATION","GAME","PERSONALIZATION","MEDICAL","FAMILY","GAME","TRAVEL_AND_LOCAL","TOOLS","BUSINESS","PRODUCTIVITY","FAMILY","FAMILY","FAMILY","FAMILY","FAMILY","FAMILY","FAMILY","FAMILY","BUSINESS","TOOLS","PERSONALIZATION","HEALTH_AND_FITNESS","PERSONALIZATION","PERSONALIZATION","FAMILY","COMMUNICATION","TOOLS","TOOLS","FAMILY","FAMILY","FAMILY","PERSONALIZATION","MEDICAL","PERSONALIZATION","MEDICAL","GAME","BOOKS_AND_REFERENCE","GAME","GAME","FAMILY","HEALTH_AND_FITNESS","FAMILY","FAMILY","FAMILY","FAMILY","FAMILY","FAMILY","FAMILY","FAMILY","GAME","GAME","FAMILY","TOOLS","TOOLS","BOOKS_AND_REFERENCE","GAME","TOOLS","FAMILY","PERSONALIZATION","MEDICAL","MEDICAL","MEDICAL","MEDICAL","MEDICAL","PRODUCTIVITY","PERSONALIZATION","TOOLS","FAMILY","TOOLS","FAMILY","MEDICAL","MEDICAL","FAMILY","COMMUNICATION","GAME","FAMILY","PHOTOGRAPHY","PRODUCTIVITY","PERSONALIZATION","MEDICAL","FAMILY","FAMILY","SPORTS","SPORTS","SPORTS","PERSONALIZATION","TOOLS","PHOTOGRAPHY","FAMILY","GAME","HEALTH_AND_FITNESS","TOOLS","FINANCE","GAME","FAMILY","GAME","GAME","GAME","TOOLS","FAMILY","WEATHER","VIDEO_PLAYERS","SPORTS","SPORTS","FAMILY","TOOLS","GAME","FAMILY","TOOLS","PERSONALIZATION","SPORTS","TOOLS","TOOLS","TOOLS","PERSONALIZATION","GAME","GAME","GAME","PERSONALIZATION","SPORTS","GAME","TRAVEL_AND_LOCAL","FAMILY","FAMILY","FAMILY","FAMILY","FAMILY","LIFESTYLE","PERSONALIZATION","FAMILY","FAMILY","BOOKS_AND_REFERENCE","FAMILY","GAME","MEDICAL","MEDICAL","SPORTS","TOOLS","GAME","LIFESTYLE","LIFESTYLE","FINANCE","MEDICAL","FAMILY","MEDICAL","FAMILY","MEDICAL","FAMILY", ...
